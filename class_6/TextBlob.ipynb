# %% [markdown]
# # **Setup**
#
# In this notebook, you will be using the NLTK's [`TextBlob`](https://textblob.readthedocs.io/en/dev/) library, which contains many common and unique NLP functions, including a sentiment analyzer.

# %%
# %reset -f
import pandas as pd, nltk
from textblob import TextBlob  # version 0.17.1
from sklearn.metrics import classification_report as rpt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import movie_reviews
_ = nltk.download(['movie_reviews', 'punkt', 'vader_lexicon'], quiet=True)
pd.set_option('max_colwidth', 0)

# %% [markdown]
# <hr style="border-top: 2px solid #606366; background: transparent;">
#
# # **Review**
#
# <font color='black'>[TextBlob](https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis) is another library that you can use to easily evaluate the sentiment of a text. Similar to [SpaCy](https://spacy.io/), TextBlob wraps your text document into an object, analyzes it, and makes numerous [attributes](https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis) and statistics accessible. In particular, it provides a sentiment polarity (as a number in $[-1,1]$ range) and sentiment subjectivity (as a number in $[0,1]$). A polarity of zero implies neutral sentiment. A subjectivity of zero indicates highly objective text.
#
# <font color='black'>Thus, the "good idea" text has a polarity of 0.7, indicating a strong positive opinion. Its subjectivity of 0.6 indicates an above average degree of opinion.

# %%
tb = TextBlob('good idea')
print(tb.sentiment.polarity)                # in [-1, 1] interval
print(round(tb.sentiment.subjectivity, 2))  # in [ 0, 1] interval
# Out:
# 0.7
# 0.6

# %% [markdown]
# ## Lots of Good Ideas
#
# <font color='black'>As with VADER, you can measure evaluate different variants of the phrase "good idea" to learn what TextBlob's sentiment analysis algorithm is sensitive to.

# %%
LsDocs = \
  ['Yes', 'No', 'Yes :-(', "good idea", "GOOD idea", "good idea!", "good idea!!!",
   "idea's good!!!!!!!!", "idea's good !!!!!!!!", "good idea!!!!!!!!",      # too many exlamations may fail
   "not a good idea", "it isn't a good idea", "good and risky idea",   # negation and multi-attitude towards the movie
   "idea is good, but risky"]           # conjunction "but" sigmals change in polarity towards dominanty phrase

def PolSub(sDoc='great idea!'):
    tb = TextBlob(sDoc)
    return (sDoc, tb.polarity, tb.subjectivity)

df = pd.DataFrame([PolSub(s) for s in LsDocs], columns=['doc','pol','subj']).set_index('doc')
df.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col0,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col1,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col0,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col1{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col2{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col3,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col4,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col11,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col12,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col13{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col5{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col6,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col7,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col8,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col9,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col10{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col3,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col4,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col5,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col6,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col7,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col8,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col9,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col10,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col11,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col12,#T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col13{
#             background-color:  #ee8468;
#             color:  #000000;
#         }</style><table id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7" ><thead>    <tr>        <th class="index_name level0" >doc</th>        <th class="col_heading level0 col0" >Yes</th>        <th class="col_heading level0 col1" >No</th>        <th class="col_heading level0 col2" >Yes :-(</th>        <th class="col_heading level0 col3" >good idea</th>        <th class="col_heading level0 col4" >GOOD idea</th>        <th class="col_heading level0 col5" >good idea!</th>        <th class="col_heading level0 col6" >good idea!!!</th>        <th class="col_heading level0 col7" >idea's good!!!!!!!!</th>        <th class="col_heading level0 col8" >idea's good !!!!!!!!</th>        <th class="col_heading level0 col9" >good idea!!!!!!!!</th>        <th class="col_heading level0 col10" >not a good idea</th>        <th class="col_heading level0 col11" >it isn't a good idea</th>        <th class="col_heading level0 col12" >good and risky idea</th>        <th class="col_heading level0 col13" >idea is good, but risky</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7level0_row0" class="row_heading level0 row0" >pol</th>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col2" class="data row0 col2" >-0.75</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col3" class="data row0 col3" >0.70</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col4" class="data row0 col4" >0.70</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col5" class="data row0 col5" >0.88</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col6" class="data row0 col6" >1.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col7" class="data row0 col7" >1.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col8" class="data row0 col8" >1.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col9" class="data row0 col9" >1.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col10" class="data row0 col10" >-0.35</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col11" class="data row0 col11" >0.70</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col12" class="data row0 col12" >0.70</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row0_col13" class="data row0 col13" >0.70</td>
#             </tr>
#             <tr>
#                         <th id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7level0_row1" class="row_heading level0 row1" >subj</th>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col1" class="data row1 col1" >0.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col2" class="data row1 col2" >1.00</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col3" class="data row1 col3" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col4" class="data row1 col4" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col5" class="data row1 col5" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col6" class="data row1 col6" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col7" class="data row1 col7" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col8" class="data row1 col8" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col9" class="data row1 col9" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col10" class="data row1 col10" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col11" class="data row1 col11" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col12" class="data row1 col12" >0.60</td>
#                         <td id="T_51c45824_fe0a_11ef_b04f_0000f8a02ea7row1_col13" class="data row1 col13" >0.60</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <font color='black'>Note that exclamations intensify the sentiment, but capitalization does not. Some negations and emoticons also impact the sentiment; however "but" and "isn't" do not.

# %% [markdown]
# ## TextBlob vs VADER on movie reviews dataset
#
# <font color='black'>Next, you'll compare TextBlob and VADER's performances on a much larger dataset. Start by loading NLTK's movie reviews, which include 1000 positive reviews and 1000 negative reviews. The cell below loads only 100 reviews from each category for performance reasons, but you can increase this number.

# %%
print('Categories:', movie_reviews.categories())
print('Total Pos#: ', len(movie_reviews.fileids('pos')), ', Neg#:', len(movie_reviews.fileids('neg')))
LsPos = [movie_reviews.raw(s) for s in movie_reviews.fileids('pos')[:100]] # retrieve a few positive reviews from files
LsNeg = [movie_reviews.raw(s) for s in movie_reviews.fileids('neg')[:100]]
LsReviews = LsPos + LsNeg     # concatenate lists of positive and negative reviews
LnPosNeg = [1] * len(LsPos) + [-1] * len(LsNeg)   # actual (binary) polarities in {-1,1} set
n = len(LsReviews)            # total count of reviews we selected
print(LsReviews[:1][0][:265], '...')
# Out:
# Categories: ['neg', 'pos']
# Total Pos#:  1000 , Neg#: 1000
# films adapted from comic books have had plenty of success , whether they're about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there's never really been a comic book like from hell before . ...

# %% [markdown]
# ### Training
#
# <font color='black'>Since TextBlob's sentiment analyzer was pre-trained on movie reviews, it should perform well on this similar corpus. VADER, by contrast, is rule-based system curated by experts. You can tune it by altering the valence of words in its vocabulary or adding/deleting words.
#
# <font color='black'>Next, you will train your own classifier on the corpus from your domain using these popular models.

# %%
from textblob import classifiers
print(', '.join(c for c in dir(classifiers) if 'Classifier' in c))
# Out:
# BaseClassifier, DecisionTreeClassifier, MaxEntClassifier, NLTKClassifier, NaiveBayesClassifier, PositiveNaiveBayesClassifier

# %% [markdown]
# ### Performance
#
# <font color='black'>Next, apply both models to the balanced subsamples. The dataframe generated below shows a small sample of TextBlob's results, including the actual sentiment polarity `vY` and the predicted valence `pPol`, which is thresholded at 0 to produce bi-polarity column `pY`.

# %%
# %time pPol = [TextBlob(s).polarity for s in LsReviews]    # predicted polarities in [-1,1] interval

pY = [-1 if p<0 else 1 for p in pPol]                     # predicted polarities in {-1,1} set
dfTB = pd.DataFrame(dict(vY=LnPosNeg, pPol=pPol, pY=pY))  # Actual bi-polarity label, predicted polarity score, predicted bi-polarity label
LnIX = list(range(20)) + list(range(n-20, n))             # index of top (pos) few and bottom (neg) few reviews
dfTB.iloc[LnIX,:].T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).set_precision(1)
# Out:
# CPU times: user 1.48 s, sys: 15.5 ms, total: 1.5 s
# Wall time: 1.51 s
# <style  type="text/css" >
# #T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col0,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col1,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col2,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col3,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col4,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col5,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col6,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col7,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col8,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col9,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col10,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col11,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col12,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col13,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col14,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col15,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col16,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col17,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col18,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col19,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col0,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col1,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col2,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col3,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col5,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col6,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col7,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col9,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col10,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col11,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col12,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col13,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col14,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col15,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col16,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col17,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col18,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col19,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col20,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col21,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col23,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col25,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col27,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col28,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col29,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col30,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col31,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col32,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col33,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col34,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col36,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col37,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col38{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col20,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col21,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col22,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col23,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col24,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col25,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col26,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col27,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col28,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col29,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col30,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col31,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col32,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col33,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col34,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col35,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col36,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col37,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col38,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row0_col39,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col4,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col8,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col22,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col24,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col26,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col35,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row2_col39{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col0,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col13,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col31{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col1,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col25,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col30,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col34{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col2{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col3,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col6,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col9,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col19{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col4{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col5,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col7{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col8{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col10,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col21,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col33{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col11{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col12{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col14{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col15{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col16,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col18{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col17{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col20,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col37{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col22{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col23,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col32{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col24{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col26{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col27{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col28{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col29{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col35,#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col39{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_52e7a27e_fe0a_11ef_b04f_0000f8a02ea7row1_col36{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }

# %% [markdown]
# <font color='black'>Notice that TextBlob appears overly positive, misclassifying far more negative reviews than positive reviews.
#
# <font color='black'>The next dataframe shows classification results for the VADER model.

# %%
sia = SentimentIntensityAnalyzer()
# %time pPol = [sia.polarity_scores(s)['compound'] for s in LsReviews]    # predicted polarities in [-1,1] interval

pY = [-1 if p<0 else 1 for p in pPol]                                   # predicted polarities in {-1,1} set
dfV = pd.DataFrame(dict(vY=LnPosNeg, pPol=pPol, pY=pY)) # Actual bi-polarity label, predicted polarity score, predicted bi-polarity label
dfV.iloc[LnIX,:].T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).set_precision(1)
# Out:
# CPU times: user 1.87 s, sys: 69.5 ms, total: 1.94 s
# Wall time: 1.96 s
# <style  type="text/css" >
# #T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col0,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col1,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col2,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col3,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col4,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col5,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col6,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col7,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col8,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col9,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col10,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col11,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col12,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col13,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col14,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col15,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col16,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col17,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col18,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col19,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col2,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col5,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col7,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col11,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col12,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col14,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col15,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col16,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col17,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col30,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col32,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col36,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col1,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col2,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col3,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col5,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col7,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col8,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col10,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col11,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col12,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col14,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col15,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col16,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col17,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col18,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col19,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col23,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col25,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col28,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col29,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col30,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col32,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col34,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col36,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col37{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col20,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col21,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col22,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col23,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col24,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col25,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col26,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col27,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col28,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col29,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col30,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col31,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col32,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col33,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col34,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col35,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col36,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col37,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col38,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row0_col39,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col39,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col0,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col4,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col6,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col9,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col13,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col20,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col21,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col22,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col24,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col26,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col27,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col31,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col33,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col35,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col38,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row2_col39{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col1{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col3,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col29,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col34,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col37{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col4{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col6{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col8{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col9,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col26,#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col31{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col10{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col13{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col18{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col19{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col20{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col21{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col22{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col23{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col24{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col25{
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col27{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col28{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col33{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col35{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_54274306_fe0a_11ef_b04f_0000f8a02ea7row1_col38{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }</style><table id="T_54274306_fe0a_11ef_b04f_0000f8a02ea7" ><thead>    <tr>        <th class="blank level0"

# %% [markdown]
# <font color='black'>Notice that VADER is more balanced in its misclassifications. It seemingly outperforms TextBlob on negative reviews and underperforms on positive reviews. Could you improve classification performance by combining these two models into an ensemble model? If you are interested, that exercise might be rewarding to explore on your own.
#
# <font color='black'>Finally, compare more comprehensive classification reports for the two model's outputs.

# %%
print(rpt(y_true=dfTB.vY, y_pred=dfTB.pY, labels=[-1,1]))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.84      0.21      0.34       100
#            1       0.55      0.96      0.70       100
#
#     accuracy                           0.58       200
#    macro avg       0.69      0.58      0.52       200
# weighted avg       0.69      0.58      0.52       200

# %%
print(rpt(y_true=dfV.vY, y_pred=dfV.pY, labels=[-1,1]))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.69      0.46      0.55       100
#            1       0.59      0.79      0.68       100
#
#     accuracy                           0.62       200
#    macro avg       0.64      0.62      0.61       200
# weighted avg       0.64      0.62      0.61       200

# %% [markdown]
# ### <font color='black'> Sentiment Metrics
# * <font color='black'>TextBlob's polarities are close to zero, while Vader's compound polarity is closer to +/-1.
#
# ### <font color='black'>Speed
#
# * <font color='black'>VADER is twice as slow, but performs much better than TextBlob on negative reviews and equally well on positive reviews.
#
#
# ### <font color='black'>Re-training
#
# * <font color='black'>TextBlob can be re-trained on additional features and datasets. It uses NLTK's `NaiveBayesAnalyzer` to associate key words with binary sentiment
# * <font color='black'>You can quickly expand VADER's vocabulary by a few words, but TextBlob requires re-training to expand its vocabulary, whether by one word or one million words. In such training a "sufficient" number of examples must be provided.

# %% [markdown]
# <hr style="border-top: 2px solid #606366; background: transparent;">
#
# # **Optional Practice**
#
# <font color='black'>Now you will practice comparing metrics for each model.
#
# As you work through these tasks, check your answers by running your code in the *#check solution here* cell, to see if you’ve gotten the correct result. If you get stuck on a task, click the See **solution** drop-down to view the answer.

# %% [markdown]
# ##  Task 1
#
# Compute f1 metrics for each sentiment class with all movie review observations with VADER and TextBlob models. Note the runtime. Do you agree with the performance and runtime comparisons made above considering this larger sample?
#
# <b>Hint:</b> Simply reuse the code above and remove slicing on <code>movie_reviews.fileids()</code>.

# %%
# check solution here

# %% [markdown]
# <font color=#606366>
#     <details><summary><font color=#B31B1B>▶ </font>See <b>solution</b>.</summary>
# <pre class="ec">
# LsPos = [movie_reviews.raw(s) for s in movie_reviews.fileids('pos')] # retrieve a few positive reviews from files
# LsNeg = [movie_reviews.raw(s) for s in movie_reviews.fileids('neg')]
# LsReviews = LsPos + LsNeg
# LnPosNeg = [1] * len(LsPos) + [-1] * len(LsNeg)   # actual (binary) polarities in {-1,1} set
#
# %time pPol = [TextBlob(s).polarity for s in LsReviews]    # predicted polarities in [-1,1] interval
# dfTB = pd.DataFrame(dict(vY=LnPosNeg, pPol=pPol, pY=[-1 if p<0 else 1 for p in pPol]))
# %time pPol = [sia.polarity_scores(s)['compound'] for s in LsReviews]    # predicted polarities in [-1,1] interval
# dfV = pd.DataFrame(dict(vY=LnPosNeg, pPol=pPol, pY=[-1 if p < 0 else 1 for p in pPol]))
# print(rpt(y_true=dfTB.vY, y_pred=dfTB.pY, labels=[-1,1]))
# print(rpt(y_true=dfV.vY, y_pred=dfV.pY, labels=[-1,1]))
#             </pre>Yes, the runtime and f1 scores are fairly similar with this larger sample as they were with the smaller sample of 200 reviews. However, VADER also appears to underperform on positive reviews with a similar f1 score.
# </details>
# </font>
#
# <hr>
